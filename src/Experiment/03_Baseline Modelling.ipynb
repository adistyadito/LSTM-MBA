# %% [markdown]
# # Importing

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, InputLayer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from tensorflow.keras.layers import Conv1D, BatchNormalization
from tensorflow.keras.metrics import AUC
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random

# %%
random.seed(42)

np.random.seed(42)

tf.random.set_seed(42)

# %% [markdown]
# # Plot Function

# %%
def plot_history(history):
    metrics = [m for m in history.history.keys() if not m.startswith('val_')]
    val_metrics = [f'val_{m}' for m in metrics if f'val_{m}' in history.history]

    plt.figure(figsize=(12,5))
    
    # ---- LOSS ----
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label='Train Loss', color='blue', linestyle='-') 
    plt.plot(history.history['val_loss'], label='Val Loss', color='red', linestyle='--')  
    plt.title('Loss Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # ---- METRIC (AUC atau Accuracy) ----
    plt.subplot(1,2,2)
    if 'auc' in history.history:
        plt.plot(history.history['auc'], label='Train AUC', color='blue', linestyle='-')
        plt.plot(history.history['val_auc'], label='Val AUC', color='red', linestyle='--')
        plt.title('ROC-AUC Curve')
        plt.ylabel('AUC')
    else:
        plt.plot(history.history['accuracy'], label='Train Acc', color='blue', linestyle='-')
        plt.plot(history.history['val_accuracy'], label='Val Acc', color='red', linestyle='--')
        plt.title('Accuracy Curve')
        plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Data Prep

# %%
data = np.load("D:\Kuliah\Tugas Akhir\Demo\src\data_preprocessed.npz")

X_train = data["X_train"]
X_test  = data["X_test"]
y_train = data["y_train"]
y_test  = data["y_test"]
vocab_size = int(data["vocab_size"])

# %% [markdown]
# # LSTM

# %%
def build_model(vocab_size,
                embedding_dim=50,
                n_layers=1,
                units=(16,),
                dropout_rate=0.3,
                lr=0.001):
    
    baseline1 = Sequential()

    # ---- EMBEDDING ----
    baseline1.add(Embedding(
        input_dim=vocab_size,
        output_dim=embedding_dim,
        mask_zero=True
    ))

    # ---- DYNAMIC LSTM STACK ----
    for i in range(n_layers):
        return_seq = (i < n_layers - 1)  
        baseline1.add(LSTM(units[i], return_sequences=return_seq))
        baseline1.add(Dropout(dropout_rate))

    # ---- DENSE ----
    baseline1.add(Dense(1, activation='sigmoid'))

    # ---- COMPILE ----
    baseline1.compile(
        optimizer=Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy', AUC(name='AUC')]
    )

    return baseline1

# %% [markdown]
# ## Baseline 1

# %%
# Build model
baseline1 = build_model(
    vocab_size=vocab_size,
    embedding_dim=64,
    n_layers=1,
    units=[128],
    dropout_rate=0.2,  
    lr=0.001
)

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6),
    ModelCheckpoint('fixed_model.keras', monitor='val_loss', mode='min', save_best_only=True)
]
    
# Fit model
history = baseline1.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - AUC: 0.4766 - accuracy: 0.4950 - loss: 0.6930 - val_AUC: 0.6563 - val_accuracy: 0.6016 - val_loss: 0.6795 - learning_rate: 0.0010
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - AUC: 0.6235 - accuracy: 0.5917 - loss: 0.6789 - val_AUC: 0.6586 - val_accuracy: 0.6016 - val_loss: 0.6612 - learning_rate: 0.0010
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - AUC: 0.6476 - accuracy: 0.6326 - loss: 0.6643 - val_AUC: 0.6906 - val_accuracy: 0.6328 - val_loss: 0.6341 - learning_rate: 0.0010
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - AUC: 0.6650 - accuracy: 0.6116 - loss: 0.6468 - val_AUC: 0.7015 - val_accuracy: 0.6406 - val_loss: 0.6272 - learning_rate: 0.0010
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - AUC: 0.6635 - accuracy: 0.6062 - loss: 0.6441 - val_AUC: 0.6839 - val_accuracy: 0.6406 - val_loss: 0.6364 - learning_rate: 0.0010
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - AUC: 0.6824 - accuracy: 0.6110 - loss: 0.6385 - val_AUC: 0.6901 - val_accuracy: 0.6719 - val_loss: 0.6243 - learning_rate: 0.0010
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - AUC: 0.6928 - accuracy: 0.6173 - loss: 0.6250 - val_AUC: 0.6907 - val_accuracy: 0.6094 - val_loss: 0.6240 - learning_rate: 0.0010
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - AUC: 0.7133 - accuracy: 0.6454 - loss: 0.6115 - val_AUC: 0.6943 - val_accuracy: 0.6719 - val_loss: 0.6213 - learning_rate: 0.0010
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - AUC: 0.7182 - accuracy: 0.6423 - loss: 0.6065 - val_AUC: 0.6988 - val_accuracy: 0.5938 - val_loss: 0.6188 - learning_rate: 0.0010
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - AUC: 0.7231 - accuracy: 0.6200 - loss: 0.6012 - val_AUC: 0.7227 - val_accuracy: 0.6641 - val_loss: 0.5994 - learning_rate: 0.0010
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - AUC: 0.7467 - accuracy: 0.6954 - loss: 0.5779 - val_AUC: 0.7145 - val_accuracy: 0.6719 - val_loss: 0.5991 - learning_rate: 0.0010
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - AUC: 0.7493 - accuracy: 0.6634 - loss: 0.5776 - val_AUC: 0.7194 - val_accuracy: 0.6562 - val_loss: 0.6049 - learning_rate: 0.0010
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - AUC: 0.7642 - accuracy: 0.7048 - loss: 0.5708 - val_AUC: 0.7242 - val_accuracy: 0.6719 - val_loss: 0.5989 - learning_rate: 0.0010
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - AUC: 0.7743 - accuracy: 0.6754 - loss: 0.5572 - val_AUC: 0.7179 - val_accuracy: 0.6406 - val_loss: 0.6162 - learning_rate: 0.0010
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - AUC: 0.7633 - accuracy: 0.6801 - loss: 0.5685 - val_AUC: 0.7241 - val_accuracy: 0.7109 - val_loss: 0.6135 - learning_rate: 0.0010
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - AUC: 0.7746 - accuracy: 0.6922 - loss: 0.5534 - val_AUC: 0.7010 - val_accuracy: 0.5859 - val_loss: 0.6443 - learning_rate: 0.0010
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - AUC: 0.7486 - accuracy: 0.6388 - loss: 0.6023 - val_AUC: 0.7126 - val_accuracy: 0.6797 - val_loss: 0.5964 - learning_rate: 0.0010
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - AUC: 0.7881 - accuracy: 0.6804 - loss: 0.5426 - val_AUC: 0.7397 - val_accuracy: 0.7266 - val_loss: 0.5934 - learning_rate: 0.0010
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - AUC: 0.8174 - accuracy: 0.7250 - loss: 0.5149 - val_AUC: 0.7400 - val_accuracy: 0.7266 - val_loss: 0.6177 - learning_rate: 0.0010
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - AUC: 0.8163 - accuracy: 0.7182 - loss: 0.5157 - val_AUC: 0.7333 - val_accuracy: 0.7109 - val_loss: 0.5959 - learning_rate: 0.0010
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - AUC: 0.8279 - accuracy: 0.7557 - loss: 0.5047 - val_AUC: 0.7523 - val_accuracy: 0.7188 - val_loss: 0.5918 - learning_rate: 0.0010
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - AUC: 0.8426 - accuracy: 0.7487 - loss: 0.4808 - val_AUC: 0.7239 - val_accuracy: 0.7188 - val_loss: 0.6380 - learning_rate: 0.0010
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - AUC: 0.8306 - accuracy: 0.7626 - loss: 0.4986 - val_AUC: 0.7983 - val_accuracy: 0.7266 - val_loss: 0.5721 - learning_rate: 0.0010
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - AUC: 0.8402 - accuracy: 0.7553 - loss: 0.4921 - val_AUC: 0.7518 - val_accuracy: 0.7266 - val_loss: 0.6525 - learning_rate: 0.0010
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - AUC: 0.8543 - accuracy: 0.7976 - loss: 0.4746 - val_AUC: 0.7265 - val_accuracy: 0.6953 - val_loss: 0.6285 - learning_rate: 0.0010
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - AUC: 0.8177 - accuracy: 0.7597 - loss: 0.5295 - val_AUC: 0.7338 - val_accuracy: 0.6953 - val_loss: 0.6444 - learning_rate: 0.0010
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - AUC: 0.8547 - accuracy: 0.7708 - loss: 0.4647 - val_AUC: 0.7570 - val_accuracy: 0.7188 - val_loss: 0.6440 - learning_rate: 0.0010
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - AUC: 0.8765 - accuracy: 0.7923 - loss: 0.4351 - val_AUC: 0.7464 - val_accuracy: 0.7031 - val_loss: 0.6422 - learning_rate: 0.0010
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - AUC: 0.8667 - accuracy: 0.7845 - loss: 0.4626 - val_AUC: 0.7332 - val_accuracy: 0.7188 - val_loss: 0.7799 - learning_rate: 0.0010
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - AUC: 0.8658 - accuracy: 0.7889 - loss: 0.4537 - val_AUC: 0.7310 - val_accuracy: 0.6953 - val_loss: 0.6524 - learning_rate: 0.0010
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - AUC: 0.8840 - accuracy: 0.8109 - loss: 0.4234 - val_AUC: 0.7546 - val_accuracy: 0.6875 - val_loss: 0.6869 - learning_rate: 0.0010
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - AUC: 0.8843 - accuracy: 0.7924 - loss: 0.4167 - val_AUC: 0.7317 - val_accuracy: 0.6953 - val_loss: 0.6780 - learning_rate: 0.0010
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - AUC: 0.8800 - accuracy: 0.7993 - loss: 0.4392 - val_AUC: 0.7264 - val_accuracy: 0.6562 - val_loss: 0.6747 - learning_rate: 0.0010

# %%
# ====== TEST CONFUSION MATRIX ======
y_pred_prob = baseline1.predict(X_test).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

roc_auc = roc_auc_score(y_test, y_pred_prob)
print("\n=evaluation")
print(f"ROC-AUC       : {roc_auc:.4f}")
print(f"Akurasi       : {np.mean(y_pred == y_test):.4f}\n")

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Neutral', 'Inhibitor']))

cm_test = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Reds',  
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Test Confusion Matrix')
plt.show()

# ====== TRAIN CONFUSION MATRIX ======
y_pred_train_prob = baseline1.predict(X_train).flatten()
y_pred_train = (y_pred_train_prob > 0.5).astype(int)

cm_train = confusion_matrix(y_train, y_pred_train)

plt.figure(figsize=(5,4))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Train Confusion Matrix')
plt.show()

plot_history(history)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# =evaluation
# ROC-AUC       : 0.7983
# Akurasi       : 0.7266
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Neutral       0.73      0.74      0.73        65
#    Inhibitor       0.73      0.71      0.72        63
#
#     accuracy                           0.73       128
#    macro avg       0.73      0.73      0.73       128
# weighted avg       0.73      0.73      0.73       128
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step

# %% [markdown]
# # Baseline 2

# %%
# Build model
baseline2 = build_model(
    vocab_size=vocab_size,
    embedding_dim=64,
    n_layers=2,
    units=[128, 64],
    dropout_rate=0.3,  
    lr=0.001
)

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6),
    ModelCheckpoint('fixed_model.keras', monitor='val_loss', mode='min', save_best_only=True)
]
    
# Fit model
history = baseline2.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,  
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - AUC: 0.4825 - accuracy: 0.4834 - loss: 0.6931 - val_AUC: 0.6540 - val_accuracy: 0.5859 - val_loss: 0.6803 - learning_rate: 0.0010
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - AUC: 0.5986 - accuracy: 0.5564 - loss: 0.6837 - val_AUC: 0.6701 - val_accuracy: 0.5859 - val_loss: 0.6616 - learning_rate: 0.0010
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - AUC: 0.6322 - accuracy: 0.6116 - loss: 0.6694 - val_AUC: 0.6841 - val_accuracy: 0.6016 - val_loss: 0.6529 - learning_rate: 0.0010
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - AUC: 0.6460 - accuracy: 0.6218 - loss: 0.6629 - val_AUC: 0.6979 - val_accuracy: 0.6094 - val_loss: 0.6228 - learning_rate: 0.0010
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - AUC: 0.6685 - accuracy: 0.6053 - loss: 0.6406 - val_AUC: 0.6916 - val_accuracy: 0.6094 - val_loss: 0.6252 - learning_rate: 0.0010
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - AUC: 0.6896 - accuracy: 0.6346 - loss: 0.6305 - val_AUC: 0.6832 - val_accuracy: 0.6172 - val_loss: 0.6350 - learning_rate: 0.0010
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - AUC: 0.7276 - accuracy: 0.6691 - loss: 0.6111 - val_AUC: 0.6869 - val_accuracy: 0.5781 - val_loss: 0.6453 - learning_rate: 0.0010
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - AUC: 0.7325 - accuracy: 0.6515 - loss: 0.5971 - val_AUC: 0.6915 - val_accuracy: 0.6094 - val_loss: 0.6357 - learning_rate: 0.0010
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - AUC: 0.7347 - accuracy: 0.6434 - loss: 0.5874 - val_AUC: 0.7061 - val_accuracy: 0.6406 - val_loss: 0.6212 - learning_rate: 0.0010
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - AUC: 0.7516 - accuracy: 0.6392 - loss: 0.5786 - val_AUC: 0.7024 - val_accuracy: 0.6172 - val_loss: 0.6809 - learning_rate: 0.0010
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - AUC: 0.7631 - accuracy: 0.6722 - loss: 0.5686 - val_AUC: 0.6884 - val_accuracy: 0.5938 - val_loss: 0.6744 - learning_rate: 0.0010
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - AUC: 0.7552 - accuracy: 0.6390 - loss: 0.5856 - val_AUC: 0.7222 - val_accuracy: 0.6562 - val_loss: 0.6400 - learning_rate: 0.0010
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - AUC: 0.7927 - accuracy: 0.6766 - loss: 0.5383 - val_AUC: 0.7088 - val_accuracy: 0.6094 - val_loss: 0.6631 - learning_rate: 0.0010
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - AUC: 0.7579 - accuracy: 0.6805 - loss: 0.5820 - val_AUC: 0.7248 - val_accuracy: 0.6953 - val_loss: 0.6708 - learning_rate: 0.0010
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - AUC: 0.8046 - accuracy: 0.7185 - loss: 0.5307 - val_AUC: 0.7139 - val_accuracy: 0.6484 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - AUC: 0.8125 - accuracy: 0.7001 - loss: 0.5123 - val_AUC: 0.7357 - val_accuracy: 0.6562 - val_loss: 0.6547 - learning_rate: 0.0010
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - AUC: 0.8315 - accuracy: 0.7421 - loss: 0.5020 - val_AUC: 0.6871 - val_accuracy: 0.6016 - val_loss: 0.6616 - learning_rate: 0.0010
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - AUC: 0.7880 - accuracy: 0.6928 - loss: 0.5509 - val_AUC: 0.6965 - val_accuracy: 0.6250 - val_loss: 0.6799 - learning_rate: 0.0010
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - AUC: 0.8281 - accuracy: 0.7265 - loss: 0.5035 - val_AUC: 0.7071 - val_accuracy: 0.6484 - val_loss: 0.7353 - learning_rate: 0.0010

# %%
# ====== TEST CONFUSION MATRIX ======
y_pred_prob = baseline2.predict(X_test).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

roc_auc = roc_auc_score(y_test, y_pred_prob)
print("\n=evaluation")
print(f"ROC-AUC       : {roc_auc:.4f}")
print(f"Akurasi       : {np.mean(y_pred == y_test):.4f}\n")

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Neutral', 'Inhibitor']))

cm_test = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Reds',  # <- ubah jadi merah
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Test Confusion Matrix')
plt.show()

# ====== TRAIN CONFUSION MATRIX ======
y_pred_train_prob = baseline2.predict(X_train).flatten()
y_pred_train = (y_pred_train_prob > 0.5).astype(int)

cm_train = confusion_matrix(y_train, y_pred_train)

plt.figure(figsize=(5,4))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Train Confusion Matrix')
plt.show()

plot_history(history)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
#
# =evaluation
# ROC-AUC       : 0.7062
# Akurasi       : 0.6406
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Neutral       0.67      0.58      0.62        65
#    Inhibitor       0.62      0.70      0.66        63
#
#     accuracy                           0.64       128
#    macro avg       0.64      0.64      0.64       128
# weighted avg       0.64      0.64      0.64       128
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step

# %% [markdown]
# ## Baseline 3

# %%
# Build model
baseline3 = build_model(
    vocab_size=vocab_size,
    embedding_dim=64,
    n_layers=3,
    units=[128, 64, 32],
    dropout_rate=0.4,  
    lr=0.001
)

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6),
    ModelCheckpoint('fixed_model.keras', monitor='val_loss', mode='min', save_best_only=True)
]
    
# Fit model
history = baseline3.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50, 
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 235ms/step - AUC: 0.4400 - accuracy: 0.4719 - loss: 0.6940 - val_AUC: 0.6094 - val_accuracy: 0.5938 - val_loss: 0.6896 - learning_rate: 0.0010
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - AUC: 0.5450 - accuracy: 0.4828 - loss: 0.6916 - val_AUC: 0.6350 - val_accuracy: 0.5859 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - AUC: 0.6269 - accuracy: 0.5952 - loss: 0.6797 - val_AUC: 0.6451 - val_accuracy: 0.5938 - val_loss: 0.6666 - learning_rate: 0.0010
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - AUC: 0.6282 - accuracy: 0.6164 - loss: 0.6727 - val_AUC: 0.6643 - val_accuracy: 0.5938 - val_loss: 0.6549 - learning_rate: 0.0010
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - AUC: 0.6383 - accuracy: 0.6061 - loss: 0.6649 - val_AUC: 0.6996 - val_accuracy: 0.6328 - val_loss: 0.6316 - learning_rate: 0.0010
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - AUC: 0.6715 - accuracy: 0.6225 - loss: 0.6421 - val_AUC: 0.7045 - val_accuracy: 0.6094 - val_loss: 0.6345 - learning_rate: 0.0010
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 252ms/step - AUC: 0.7024 - accuracy: 0.6472 - loss: 0.6295 - val_AUC: 0.6730 - val_accuracy: 0.6094 - val_loss: 0.6509 - learning_rate: 0.0010
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - AUC: 0.7291 - accuracy: 0.6595 - loss: 0.6130 - val_AUC: 0.7123 - val_accuracy: 0.6250 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - AUC: 0.7143 - accuracy: 0.6415 - loss: 0.6170 - val_AUC: 0.7161 - val_accuracy: 0.6094 - val_loss: 0.6140 - learning_rate: 0.0010
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - AUC: 0.7608 - accuracy: 0.6774 - loss: 0.5916 - val_AUC: 0.7248 - val_accuracy: 0.6172 - val_loss: 0.6155 - learning_rate: 0.0010
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - AUC: 0.7815 - accuracy: 0.6901 - loss: 0.5577 - val_AUC: 0.7211 - val_accuracy: 0.6172 - val_loss: 0.6177 - learning_rate: 0.0010
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - AUC: 0.7813 - accuracy: 0.7006 - loss: 0.5608 - val_AUC: 0.7223 - val_accuracy: 0.6406 - val_loss: 0.6047 - learning_rate: 0.0010
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - AUC: 0.7853 - accuracy: 0.6907 - loss: 0.5535 - val_AUC: 0.7166 - val_accuracy: 0.6094 - val_loss: 0.6317 - learning_rate: 0.0010
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - AUC: 0.7521 - accuracy: 0.6752 - loss: 0.5819 - val_AUC: 0.7155 - val_accuracy: 0.6406 - val_loss: 0.6406 - learning_rate: 0.0010
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - AUC: 0.7589 - accuracy: 0.6746 - loss: 0.5767 - val_AUC: 0.7144 - val_accuracy: 0.6562 - val_loss: 0.6416 - learning_rate: 0.0010
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - AUC: 0.7974 - accuracy: 0.7243 - loss: 0.5414 - val_AUC: 0.7032 - val_accuracy: 0.6641 - val_loss: 0.6604 - learning_rate: 0.0010
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - AUC: 0.8170 - accuracy: 0.7212 - loss: 0.5149 - val_AUC: 0.6946 - val_accuracy: 0.6484 - val_loss: 0.6760 - learning_rate: 0.0010
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - AUC: 0.8234 - accuracy: 0.7596 - loss: 0.5155 - val_AUC: 0.7098 - val_accuracy: 0.6719 - val_loss: 0.6751 - learning_rate: 0.0010
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - AUC: 0.8287 - accuracy: 0.7456 - loss: 0.4982 - val_AUC: 0.7205 - val_accuracy: 0.6172 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - AUC: 0.8111 - accuracy: 0.7295 - loss: 0.5210 - val_AUC: 0.7066 - val_accuracy: 0.6328 - val_loss: 0.7272 - learning_rate: 0.0010
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 249ms/step - AUC: 0.8310 - accuracy: 0.7270 - loss: 0.4879 - val_AUC: 0.6946 - val_accuracy: 0.6250 - val_loss: 0.8101 - learning_rate: 0.0010
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - AUC: 0.8491 - accuracy: 0.7751 - loss: 0.4691 - val_AUC: 0.7171 - val_accuracy: 0.6797 - val_loss: 0.7664 - learning_rate: 0.0010

# %%
# ====== TEST CONFUSION MATRIX ======
y_pred_prob = baseline3.predict(X_test).flatten()
y_pred = (y_pred_prob > 0.5).astype(int)

roc_auc = roc_auc_score(y_test, y_pred_prob)
print("\n=evaluation")
print(f"ROC-AUC       : {roc_auc:.4f}")
print(f"Akurasi       : {np.mean(y_pred == y_test):.4f}\n")

print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Neutral', 'Inhibitor']))

cm_test = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm_test, annot=True, fmt='d', cmap='Reds',  
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Test Confusion Matrix')
plt.show()

# ====== TRAIN CONFUSION MATRIX ======
y_pred_train_prob = baseline3.predict(X_train).flatten()
y_pred_train = (y_pred_train_prob > 0.5).astype(int)

cm_train = confusion_matrix(y_train, y_pred_train)

plt.figure(figsize=(5,4))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Neutral', 'Inhibitor'],
            yticklabels=['Neutral', 'Inhibitor'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Train Confusion Matrix')
plt.show()

plot_history(history)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
#
# =evaluation
# ROC-AUC       : 0.7214
# Akurasi       : 0.6406
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Neutral       0.67      0.57      0.62        65
#    Inhibitor       0.62      0.71      0.66        63
#
#     accuracy                           0.64       128
#    macro avg       0.64      0.64      0.64       128
# weighted avg       0.65      0.64      0.64       128
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
